# %% [markdown]
# # Machine Learning LAB 2: SUPPORT VECTOR MACHINES
#
# Course 2023/24: *M. Caligiuri*, *P. Talli*, *F. Lincetto*, *F. Chiariotti*, *P. Zanuttigh*
#
# The notebook contains some simple tasks to be performed with **SUPPORT VECTOR MACHINES (SVM)**.
#
# Complete all the **required code sections** and **answer to all the questions**.
#
# ### IMPORTANT for the evaluation score:
#
# 1. **Read carefully all cells** and **follow the instructions**.
# 2. **Re-run all the code from the beginning** to obtain the results for the final version of your notebook, since this is the way we will do it before evaluating your notebooks.
# 3. Make sure to fill the code in the appropriate places **without modifying the template**, otherwise you risk breaking later cells.
# 4. Please **submit the jupyter notebook file (.ipynb)**, do not submit python scripts (.py) or plain text files. **Make sure that it runs fine with the restat&run all command**.
# 5. **Answer the questions in the appropriate cells**, not in the ones where the question is presented.

# %% [markdown]
# ## Weather Classification with Support Vector Machines
#
# In this notebook we are going to explore the use of Support Vector Machines (SVM) for weather classification. We will use a dataset collected using the Luxottica **iSee** glasses. These devices provide multiple **sensors mounted inside the glasses**, which can be accessed through a bluetooth connection.
#
# ![I-SEE Glasses](data/isee.png "I-SEE")
#
# The dataset corresponds to 8 hours of atmospherical data recordings sampled every 3 seconds.
#
# The dataset labels are the following:
#
# | ID  | Label       |
# | :-: | :-:         |
# | 0   | Sunny       |
# | 1   | Rain        |
# | 2   | Cloudy      |
# | 3   | Mostly Clear|
#
# ---

# %% [markdown]
# ## Preliminary step
#
# Place your **name** and **ID number** (matricola) in the cell below. <br>
# Also recall to **save the file as Surname_Name_LAB02.ipynb**, failure to do so will incur in a **lower grade**.

# %% [markdown]
# **Student name**: Andrea Turci
#
# **ID Number**: 2106724

# %% [markdown]
# ---

# %% [markdown]
# ## Import all the necessary Python libraries

# %%
# %matplotlib inline

import numpy as np
import scipy as sp
import itertools
from matplotlib import pyplot as plt

import sklearn.metrics as skm
from sklearn.svm import SVC
from sklearn import linear_model

from sklearn.metrics import confusion_matrix

# %% [markdown]
# ---

# %% [markdown]
# ## Define the heplper functions
#
# In this section you will find some helper functions (some already implemented, some to be implemented by you) that will be used in the following sections.
# 1. `load_dataset` -> to load the dataset from the file `data/lux.npz`,
# 2. `plot_input` -> to plot the input data,
# 3. `k_split` ->  to split the trainig dataset in k different folds,
# 4. `k_fold_cross_validation` -> to perform the k-fold cross validation.
#
# **DO NOT CHANGE THE PRE-WRITTEN CODE UNLESS OTHERWISE SPECIFIED**

# %%
# Helper function to load the dataset
def load_dataset(path: str) -> (np.ndarray, np.ndarray):
    with np.load(path) as data:
        x, y = data["x"], data["y"]
        
        # Normalize the data
        x -= x.mean(axis=0)
        x /= x.std(axis=0)
        
    return x, y

# %%
# Function for plotting a image and printing the corresponding label
def plot_input(X_matrix: np.ndarray, labels: np.ndarray) -> None:
    fig = plt.figure()
    ax = fig.add_subplot(projection="3d")
    cmap = plt.cm.get_cmap('Accent', 4)
    im = ax.scatter(X_matrix[:,0], X_matrix[:,1], X_matrix[:,2], c=labels, cmap=cmap)
    im.set_clim(-0.5, 3.5)
    cbar=fig.colorbar(im, ticks=[0,1,2,3], orientation='vertical', cmap=cmap)
    cbar.ax.set_yticklabels(['Sunny', 'Rainy','Cloudy', 'Mostly clear']) 

    ax.set_xlabel('Humidity')
    ax.set_ylabel('Temperature')
    ax.set_zlabel('Atmospheric Pressure')

# %%
# Function to split the dataset in k different folds
def k_split(x: np.ndarray, y:np.ndarray, k: int, shuffle: bool = True) -> tuple[list[np.ndarray], list[np.ndarray]]:
    # Shuffle the dataset
    if shuffle:
        # Create a list of indices
        idx = np.arange(x.shape[0])
        # Randomly shuffle the indices
        np.random.shuffle(idx)
        # Shuffle the dataset
        x = x[idx]
        y = y[idx]

    # Split the dataset in k folds
    # ADD YOUR CODE HERE
    x_folds = []  # Lista per i folds di x
    y_folds = []  # Lista per i folds di y

    size_of_fold = int(len(x)/k)


    for i in range(0, k):
        x_dataset = x[(i*size_of_fold):((i+1)*size_of_fold)]
        y_dataset = y[(i*size_of_fold):((i+1)*size_of_fold)]

        x_folds.append(x_dataset)
        y_folds.append(y_dataset)

    return x_folds, y_folds

# %%
# Function to perform the k-fold cross validation
def k_fold_cross_validation(x_train: np.ndarray, y_train: np.ndarray, k: int, model: SVC, parameters: dict) -> tuple[tuple, tuple]:
    # Define the folds for the cross validation
    x_folds, y_folds = k_split(x_train, y_train, k)

    # Build a list containing all of the possible combination of parameters
    params = list(itertools.product(*parameters.values()))      #parameters is a dictionary

    # Initialize the dictionary of results
    results = {k: 0 for k in params}    #result is a dictionary.  le chiavi sono le combinazioni di parametri (elementi di 
                                        # params), e i valori sono inizializzati a 0.

    # For each param combination, perform the SVM training and testing
    for param in params:
        param = dict(zip(parameters.keys(), param))     #La combinazione corrente di parametri viene convertita in un dizionario
                                                        #Forse adesso param è dizionario con la precisa combinazione di parametri (presi da params)
        fold_accuracies = []
        
        # ADD YOUR CODE HERE
        for fold in range(k):
            # Training: Use all folds except the current one for training
            x_train_fold = np.concatenate([x_folds[i] for i in range(k) if i != fold])
            y_train_fold = np.concatenate([y_folds[i] for i in range(k) if i != fold])

            # Testing: Use the current fold for testing
            x_test_fold = x_folds[fold]
            y_test_fold = y_folds[fold]

    
            model.set_params(**param)

            # Train the SVM model
            model.fit(x_train_fold, y_train_fold)

            # Test the SVM model
            y_pred_fold = model.predict(x_test_fold)

            # Evaluate accuracy and append to fold_accuracies
            fold_accuracies.append(model.score(x_test_fold, y_test_fold))
        

        # Compute the mean accuracy
        results[tuple(param.values())] = round(np.mean(fold_accuracies), 4)
    
    # Find the best parameters
    best_parameters = dict(zip(parameters.keys(), params[np.argmax(list(results.values()))]))
    best_accuracy = np.max(list(results.values()))
    best = (best_parameters, best_accuracy)

    # Add the param name to the results
    results = [({k: v for k, v in zip(parameters.keys(), p)}, a) for p, a in results.items()]

    return best, results

# %% [markdown]
# ---

# %% [markdown]
# ## A) Hyper-parameter search
#
# ### TO DO (A.0)
#
# **Set** the random **seed** using your **ID**. If you need to change it for testing add a constant explicitly, eg.: 1234567 + 1

# %%
# fix your ID ("numero di matricola") and the seed for random generator
# as usual you can try different seeds by adding a constant to the number:
# ID = 1234567 + X
ID = 2106724 + 3
np.random.seed(ID)

# %% [markdown]
# Before proceding to the training steps, we **load the dataset and split it** in training and test set (while the **training** set is **typically larger**, here we set the number of training samples to 1000 and 4000 for the test data).
# The **split** is **performed after applying a random permutation** to the dataset, such permutation will **depend on the seed** you set above.

# %%
# Load the dataset using the helper function
X, y = load_dataset("data/lux.npz")
print(X.shape, y.shape)
# Out:
# (15099, 3) (15099,)

# %%
# The task is quite easy, let's add noise to make it more challenging!
# You can try without noise (comment the next 2 lines, easy task), with the suggested amount of noise,
# or play with the suggested amount of noise 

noise = np.random.normal(0, 0.1, X.shape)
X = X + noise

# %% [markdown]
# ### TO DO (A.1)
#
# **Divide** the **data into training and test set** (for this part use 1000 samples in the **first** set, 4000 in the **second** one). Make sure that each label is present at least 10 times in training. If it is not, then keep adding permutations to the initial data until this happens.

# %%
# Random permute the data and split into training and test taking the first 1000
# data samples as training and 4000 samples as test

#Need to perform the control in the instructions
condition_is_met = False

while not condition_is_met:
    permutation = np.random.permutation(len(X))

    X = X[permutation]

    y = y[permutation]

    m_training = 1000
    m_test = 4000

    X_train = X[:m_training]
    y_train = y[:m_training]

    labels, freqs = np.unique(y_train, return_counts=True)
    condition_is_met= all(count >=10 for count in freqs)



X_test = X[m_training:(m_training+m_test)]
y_test = y[m_training:(m_training+m_test)]


print("X_train shape:", X_train.shape,"X_test shape:", X_test.shape,"||","y_train shape:",  y_train.shape,"y_test shape:", y_test.shape)
print("Labels in training dataset: ", labels)
print("Frequencies in training dataset: ", freqs)
# Out:
# X_train shape: (1000, 3) X_test shape: (4000, 3) || y_train shape: (1000,) y_test shape: (4000,)
# Labels in training dataset:  [0. 1. 2. 3.]
# Frequencies in training dataset:  [402 144 391  63]

# %%
#Let's try the plotting function
plot_input(X_train,y_train)
# Out:
# /tmp/ipykernel_5974/2138009539.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Accent', 4)

# %% [markdown]
# ### TO DO (A.2)
#
# Use a SVM classfier with cross validation to pick a model. Use a 4-fold cross-validation. Let's start with a Linear kernel.

# %%
# Parameters for linear SVM
parameters = {'C': [ 0.01, 0.1, 1, 10]}

# Define the model (without parameters)
svm = SVC(kernel ="linear")

# Perform the K-fold cross validation
best, results = k_fold_cross_validation(X_train, y_train, 4, svm, parameters)

print ('RESULTS FOR LINEAR KERNEL')
print()

print("Best parameter set found:")
print(best[0])

print("Score with best parameter:")
print(best[1])

print()
print("All scores on the grid:")
for i in results:
    print(i[0], i[1])
# Out:
# RESULTS FOR LINEAR KERNEL
#
# Best parameter set found:
# {'C': 10}
# Score with best parameter:
# 0.911
#
# All scores on the grid:
# {'C': 0.01} 0.788
# {'C': 0.1} 0.885
# {'C': 1} 0.907
# {'C': 10} 0.911

# %% [markdown]
# ### TO DO (A.3)
#
# Pick a model for the Polynomial kernel with degree=2.

# %%
# Parameters for linear SVM
parameters = {'C': [0.01, 0.1, 1],'gamma':[0.01,0.1,1.]}

# Define an SVM with poly of degree 2 kernel (without parameters)
poly2_svm = SVC(kernel="poly", degree=2)

# Perform the K-fold cross validation
best, results = k_fold_cross_validation(X_train, y_train, 4, poly2_svm, parameters)

print ('RESULTS FOR POLY DEGREE=2 KERNEL')
print()
print("Best parameter set found:")
print(best[0])

print("Score with best parameter:")
print(best[1])
print()
print("All scores on the grid:")

for i in results:
    print(i[0], i[1])
# Out:
# RESULTS FOR POLY DEGREE=2 KERNEL
#
# Best parameter set found:
# {'C': 1, 'gamma': 1.0}
# Score with best parameter:
# 0.944
#
# All scores on the grid:
# {'C': 0.01, 'gamma': 0.01} 0.361
# {'C': 0.01, 'gamma': 0.1} 0.361
# {'C': 0.01, 'gamma': 1.0} 0.848
# {'C': 0.1, 'gamma': 0.01} 0.361
# {'C': 0.1, 'gamma': 0.1} 0.793
# {'C': 0.1, 'gamma': 1.0} 0.932
# {'C': 1, 'gamma': 0.01} 0.361
# {'C': 1, 'gamma': 0.1} 0.848
# {'C': 1, 'gamma': 1.0} 0.944

# %% [markdown]
# ### TO DO (A.4)
#
# Now let's try a higher degree for the polynomial kernel (e.g., 3rd degree).

# %%
# Parameters for poly with higher degree kernel
parameters = {'C': [0.01, 0.1, 1],'gamma':[0.01,0.1, 1]}

# Define an SVM with poly of higher degree kernel (without parameters)
degree = 3
poly_svm = SVC(kernel="poly", degree=degree)

# Perform the K-fold cross validation
best, results = k_fold_cross_validation(X_train, y_train, 4, poly_svm, parameters)

print (f"RESULTS FOR POLY DEGREE={degree} KERNEL")
print()

print("Best parameter set found:")
print(best[0])

print("Score with best parameter:")
print(best[1])
print()
print("All scores on the grid:")
for i in results:
    print(i[0], i[1])
# Out:
# RESULTS FOR POLY DEGREE=3 KERNEL
#
# Best parameter set found:
# {'C': 1, 'gamma': 1}
# Score with best parameter:
# 0.924
#
# All scores on the grid:
# {'C': 0.01, 'gamma': 0.01} 0.383
# {'C': 0.01, 'gamma': 0.1} 0.383
# {'C': 0.01, 'gamma': 1} 0.863
# {'C': 0.1, 'gamma': 0.01} 0.383
# {'C': 0.1, 'gamma': 0.1} 0.516
# {'C': 0.1, 'gamma': 1} 0.909
# {'C': 1, 'gamma': 0.01} 0.383
# {'C': 1, 'gamma': 0.1} 0.79
# {'C': 1, 'gamma': 1} 0.924

# %% [markdown]
# ### TO DO (A.5)
#
# Pick a model for the Radial Basis Function kernel:

# %%
# Parameters for rbf SVM
parameters = {'C': [0.1, 1, 10, 100],'gamma':[0.001, 0.01, 0.1,1]}

# Define an SVM with rbf kernel (without parameters)
rbf_svm = SVC(kernel="rbf")

# Perform the K-fold cross validation
best, results = k_fold_cross_validation(X_train, y_train, 4, rbf_svm, parameters)

print ('RESULTS FOR rbf KERNEL')
print()

print("Best parameter set found:")
print(best[0])

print("Score with best parameter:")
print(best[1])
print()
print("All scores on the grid:")
for i in results:
    print(i[0], i[1])
# Out:
# RESULTS FOR rbf KERNEL
#
# Best parameter set found:
# {'C': 100, 'gamma': 1}
# Score with best parameter:
# 0.99
#
# All scores on the grid:
# {'C': 0.1, 'gamma': 0.001} 0.365
# {'C': 0.1, 'gamma': 0.01} 0.638
# {'C': 0.1, 'gamma': 0.1} 0.842
# {'C': 0.1, 'gamma': 1} 0.945
# {'C': 1, 'gamma': 0.001} 0.633
# {'C': 1, 'gamma': 0.01} 0.797
# {'C': 1, 'gamma': 0.1} 0.944
# {'C': 1, 'gamma': 1} 0.98
# {'C': 10, 'gamma': 0.001} 0.797
# {'C': 10, 'gamma': 0.01} 0.899
# {'C': 10, 'gamma': 0.1} 0.973
# {'C': 10, 'gamma': 1} 0.987
# {'C': 100, 'gamma': 0.001} 0.879
# {'C': 100, 'gamma': 0.01} 0.955
# {'C': 100, 'gamma': 0.1} 0.981
# {'C': 100, 'gamma': 1} 0.99

# %% [markdown]
# ### TO DO (A.Q1) [Answer the following]
#
# What do you observe when using RBF and polynomial kernels on this dataset ?

# %% [markdown]
# **ANSWER A.Q1:**:
# I report here the best values for the parameters for each kernel model. <br>
#
# RBF: Best parameter set found: C = 100, gamma = 1. Score with best parameter: 0.99. <br>
# POLYNOMIAL DEGREE 2: Best parameter set found: C = 1, gamma = 1. Score with best parameter: 0.944 <br>
# POLYNOMIAL DEGREE 3: Best parameter set found: C = 1, gamma = 1. Score with best parameter: 0.924 <br>
#
# We can observe that they all return a good score, comparable to each others, but better for the RBF kernel model. Moreover, the best value for gamma is the same, in this run and with this seed

# %% [markdown]
# ### TO DO (A.6)
# Report here the best SVM kernel and parameters

# %%
# Get training and test error for the best SVM model from CV
best_svm = SVC(kernel="rbf", C=10, gamma=1)

# Run the svm model on the whole training set
best_svm.fit(X_train, y_train)

# Compute the errors
# (error is 1 - svm.score)
training_error = 1 - best_svm.score(X_train, y_train)
test_error = 1 - best_svm.score(X_test, y_test)

print ("Best SVM training error: %f" % training_error)
print ("Best SVM test error: %f" % test_error)
# Out:
# Best SVM training error: 0.007000
# Best SVM test error: 0.013000

# %% [markdown]
# ### TO DO (A.7)
#
# Analyze how the gamma parameter (inversely proportional to standard deviation of Gaussian Kernel) impact the performances of the classifier

# %%
# Test with different values of gamma
# use rbf kernel and C=1

# Set gamma values
gamma_values = np.logspace(-5,2,8)
print(gamma_values)
# Out:
# [1.e-05 1.e-04 1.e-03 1.e-02 1.e-01 1.e+00 1.e+01 1.e+02]

# %%
train_acc_list, test_acc_list = [], []

C_value = 1

for gamma in gamma_values:
    rbf_svm = SVC(kernel = "rbf", C = C_value, gamma = gamma)

    rbf_svm.fit(X_train, y_train)
    
    train_acc = rbf_svm.score(X_train, y_train)
    test_acc = rbf_svm.score(X_test, y_test)

    train_acc_list.append(train_acc)
    test_acc_list.append(test_acc)

    
    print("Gamma: ", gamma, "Training Accuracy: ", train_acc, "Test Accuracy: ", test_acc)


print("Training Accuracies:", train_acc_list)
print("Test Accuracies:", test_acc_list)

    


# ADD YOUR CODE TO TRAIN THE SVM MULTIPLE TIMES WITH THE DIFFERENT VALUES OF GAMMA
# PLACE THE TRAIN AND TEST ACCURACY FOR EACH TEST IN THE TRAIN AND TEST ACCURACY LISTS
# Out:
# Gamma:  9.999999999999999e-06 Training Accuracy:  0.402 Test Accuracy:  0.402
# Gamma:  9.999999999999999e-05 Training Accuracy:  0.402 Test Accuracy:  0.402
# Gamma:  0.001 Training Accuracy:  0.63 Test Accuracy:  0.6285
# Gamma:  0.01 Training Accuracy:  0.817 Test Accuracy:  0.79775
# Gamma:  0.09999999999999999 Training Accuracy:  0.952 Test Accuracy:  0.94225
# Gamma:  1.0 Training Accuracy:  0.985 Test Accuracy:  0.985
# Gamma:  10.0 Training Accuracy:  0.994 Test Accuracy:  0.9875
# Gamma:  100.0 Training Accuracy:  0.999 Test Accuracy:  0.931
# Training Accuracies: [0.402, 0.402, 0.63, 0.817, 0.952, 0.985, 0.994, 0.999]
# Test Accuracies: [0.402, 0.402, 0.6285, 0.79775, 0.94225, 0.985, 0.9875, 0.931]

# %%
# Plot
fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].plot(gamma_values, train_acc_list)
ax[0].set_xscale('log')
ax[0].set_xlabel('gamma')
ax[0].set_ylabel('Train accuracy')
ax[0].grid(True)

ax[1].plot(gamma_values, test_acc_list)
ax[1].set_xscale('log')
ax[1].set_xlabel('gamma')
ax[1].set_ylabel('Test accuracy')
ax[1].grid(True)

plt.show()

# %% [markdown]
# ## B) More data
# Now let's do the same but using more data points for training.

# %% [markdown]
# ### TO DO (B.0)
#
# Choose a higher number of data points (e.g. x = 10000) for training data depending on your computing capability.

# %%
X = X[permutation]
y = y[permutation]

m_training = 10000

X_train, X_test = X[:m_training], X[m_training:]
y_train, y_test = y[:m_training], y[m_training:]

labels, freqs = np.unique(y_train, return_counts=True)
print("Labels in training dataset: ", labels)
print("Frequencies in training dataset: ", freqs)

# initialize support variables for boundaries visualization
granularity = 25
x_max = np.abs(X).max()
x_range = np.linspace(-x_max, x_max, granularity)
x_grid = np.stack(np.meshgrid(x_range, x_range, x_range)).reshape(3, -1).T
# Out:
# Labels in training dataset:  [0. 1. 2. 3.]
# Frequencies in training dataset:  [4074 1653 3647  626]

# %% [markdown]
# ### TO DO (B.1)
#
# Let's try to use SVM with parameters obtained from the best model for $m_{training} =  10000$. Since it may take a long time to run, you can decide to just let it run for some time and stop it if it does not complete. If you decide to do this, report it in the TO DO (C.Q1) cell below.

# %%
# Get training and test error for the best SVM model from CV

best_svm = SVC(kernel="rbf", C=10, gamma=1)

# Run the svm model on the whole training set
best_svm.fit(X_train, y_train)

# Compute the errors
# (error is 1 - svm.score)
training_error = 1 - best_svm.score(X_train, y_train)
test_error = 1 - best_svm.score(X_test, y_test)

print ("Best SVM training error: %f" % training_error)
print ("Best SVM test error: %f" % test_error)
# Out:
# Best SVM training error: 0.009000
# Best SVM test error: 0.012551

# %% [markdown]
# ## C) Boundaries Visualization
#
# Now let us plot the classification boundaries.

# %% [markdown]
# ### TO DO (C.0)
#
# Use the SVM to predict on the test set X_test.

# %%
rbf_svm_test = best_svm.predict(X_test)

# %% [markdown]
# We constructed a grid of all possible combinations of input values, we now use it to extract the classification boundaries of the three classifiers by having them predict on each input.

# %%
#rbf_SVM_grid = rbf_svm.predict(x_grid)
rbf_SVM_grid = best_svm.predict(x_grid)      #moficato da me


rbf_SVM_m = y_test == rbf_svm_test

fig = plt.figure(figsize=(20,36))
ax1 = fig.add_subplot(1, 3, 1, projection="3d")
ax2 = fig.add_subplot(1, 3, 2, projection="3d")
ax3 = fig.add_subplot(1, 3, 3, projection="3d")

ax1.scatter(x_grid[:,0], x_grid[:,1], x_grid[:,2], c=rbf_SVM_grid, linewidth=0, marker="s", alpha=.05,cmap='Accent')

ax1.scatter(X_test[rbf_SVM_m,0], X_test[rbf_SVM_m,1], X_test[rbf_SVM_m,2], c=y_test[rbf_SVM_m], linewidth=.5, edgecolor="k", marker=".",cmap='Accent')
ax1.scatter(X_test[~rbf_SVM_m,0], X_test[~rbf_SVM_m,1], X_test[~rbf_SVM_m,2], c=y_test[~rbf_SVM_m], linewidth=1, edgecolor="r", marker=".",cmap='Accent')
ax1.set_xlim([-x_max, x_max])
ax1.set_ylim([-x_max, x_max])
ax1.set_zlim([-x_max, x_max])

########################################################################################
best_svm_linear = SVC(kernel="linear", C=10)
best_svm_linear.fit(X_train, y_train)
linear_svm_test = best_svm_linear.predict(X_test)

#linear_SVM_grid = svm.predict(x_grid)
linear_SVM_grid = best_svm_linear.predict(x_grid)

linear_SVM_m = y_test == linear_svm_test

ax2.scatter(x_grid[:,0], x_grid[:,1], x_grid[:,2], c=linear_SVM_grid, linewidth=0, marker="s", alpha=.05,cmap='Accent')

ax2.scatter(X_test[linear_SVM_m,0], X_test[linear_SVM_m,1], X_test[linear_SVM_m,2], c=y_test[linear_SVM_m], linewidth=.5, edgecolor="k", marker=".",cmap='Accent')
ax2.scatter(X_test[~linear_SVM_m,0], X_test[~linear_SVM_m,1], X_test[~linear_SVM_m,2], c=y_test[~linear_SVM_m], linewidth=1, edgecolor="r", marker=".",cmap='Accent')
ax2.set_xlim([-x_max, x_max])
ax2.set_ylim([-x_max, x_max])
ax2.set_zlim([-x_max, x_max])

#######################################################################################
best_svm_poly = SVC(kernel="poly",degree=3, C=1, gamma=1)
best_svm_poly.fit(X_train, y_train)
poly_svm_test = best_svm_poly.predict(X_test)

#poly_SVM_grid = poly_svm.predict(x_grid)
poly_SVM_grid = best_svm_poly.predict(x_grid)

poly_SVM_m = y_test == poly_svm_test

ax3.scatter(x_grid[:,0], x_grid[:,1], x_grid[:,2], c=poly_SVM_grid, linewidth=0, marker="s", alpha=.05,cmap='Accent')

ax3.scatter(X_test[poly_SVM_m,0], X_test[poly_SVM_m,1], X_test[poly_SVM_m,2], c=y_test[poly_SVM_m], linewidth=.5, edgecolor="k", marker=".",cmap='Accent')
ax3.scatter(X_test[~poly_SVM_m,0], X_test[~poly_SVM_m,1], X_test[~poly_SVM_m,2], c=y_test[~poly_SVM_m], linewidth=1, edgecolor="r", marker=".",cmap='Accent')
ax3.set_xlim([-x_max, x_max])
ax3.set_ylim([-x_max, x_max])
ax3.set_zlim([-x_max, x_max])
# Out:
# (-2.793504357411112, 2.793504357411112)

# %% [markdown]
# ### TO DO (C.Q1) [Answer the following]**
#
# Compare and discuss the results from SVM with m=1000 and with m=10000 (or whatever value you set) training data points. If you stopped the SVM, include such aspect in your comparison.

# %% [markdown]
# **ANSWER C.Q1:**
#
# m = 1000 <br>
# Best SVM training error: 0.007000 <br>
# Best SVM test error: 0.013000 <br>
#
# m = 10000 <br>
# Best SVM training error: 0.009000 <br>
# Best SVM test error: 0.012551<br>
#
# We can observe that the training error increased in the latter case since we are considering 10 times data points, and we expect to see an increased error. However, the error on the test decreased, as expected, since it is also our goal.<br>

# %% [markdown]
# ### TO DO (C.1)
#
# Plot the confusion matrix for the SVM classifier. The confusion matrix has one column for each predicted label and one row for each true label.
# It shows for each class in the corresponding row how many samples belonging to that class gets each possible output label. Notice that the diagonal contains the correctly classified samples, while the other cells correspond to errors. You can obtain it with the sklearn.metrics.confusion_matrix function (see the documentation). You can also print also the normalized confusion matrix.

# %%
np.set_printoptions(precision=2, suppress=True) # for better aligned printing of confusion matrix use floatmode='fixed'

u, counts = np.unique(y_test, return_counts=True)
print("Labels and frequencies in test set: ", counts)

confusion_SVM = confusion_matrix(y_test, rbf_svm_test)
print("\n Confusion matrix SVM  \n \n", confusion_SVM)
print("\n Confusion matrix SVM (normalized)   \n \n", confusion_SVM /counts[:,None] )
# Out:
# Labels and frequencies in test set:  [2044  875 1876  304]
#
#  Confusion matrix SVM
#
#  [[2044    0    0    0]
#  [   0  838   36    1]
#  [   0   26 1850    0]
#  [   0    1    0  303]]
#
#  Confusion matrix SVM (normalized)
#
#  [[1.   0.   0.   0.  ]
#  [0.   0.96 0.04 0.  ]
#  [0.   0.01 0.99 0.  ]
#  [0.   0.   0.   1.  ]]

# %%
fig = plt.figure()
    
im = plt.imshow(confusion_SVM /counts[:,None], cmap="Blues",interpolation='nearest')
plt.xticks([0,1,2,3], ['Sunny', 'Rainy','Cloudy', 'Mostly clear'],ha="right",rotation=30)
plt.yticks([0,1,2,3], ['Sunny', 'Rainy','Cloudy', 'Mostly clear'],ha="right",rotation=30)
cm = confusion_SVM /counts[:,None]
fmt = '.2f'
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], fmt),
        ha="center", va="center",
        color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
fig.colorbar(im, location='bottom')  
plt.show()

# %% [markdown]
# ### TO DO (C.Q2) [Answer the following]
#
# Have a look at the confusion matrix and comment on the obtained accuracies. Why some classes have lower accuracies and others an higher one? Make some guesses on the possible causes.

# %% [markdown]
# **ANSWER C.Q2:**
#
# As we can see we obtained a confusion matrix with unit elements in the diagonal terms, making it similar to the identity matrix, meaning that the predicted labels are correct most of the time. <br>
# Moreover, we can see that the "sunny" and "mostly clear" elements are well predicted, instead the "Rainy" and "cloudy" have slightly small, but non-zero errors. In particular, observing that the only non-diagonal elements that are non-zero are "cloudy" and "rainy", we can deduce that the algorithm got confused between cloudy and rainy, and not on the other two labels. This is in agreement on what expected from a intuitive point of view, and also having a look to the depicted plots, where we can see that cloudy and rainy are the two labels that overlap the most.

# %%
#I try to do the same for linear model
np.set_printoptions(precision=2, suppress=True) # for better aligned printing of confusion matrix use floatmode='fixed'

u, counts = np.unique(y_test, return_counts=True)
print("Labels and frequencies in test set: ", counts)

confusion_SVM = confusion_matrix(y_test, linear_svm_test)
print("\n Confusion matrix SVM  \n \n", confusion_SVM)
print("\n Confusion matrix SVM (normalized)   \n \n", confusion_SVM /counts[:,None] )


fig = plt.figure()
    
im = plt.imshow(confusion_SVM /counts[:,None], cmap="Blues",interpolation='nearest')
plt.xticks([0,1,2,3], ['Sunny', 'Rainy','Cloudy', 'Mostly clear'],ha="right",rotation=30)
plt.yticks([0,1,2,3], ['Sunny', 'Rainy','Cloudy', 'Mostly clear'],ha="right",rotation=30)
cm = confusion_SVM /counts[:,None]
fmt = '.2f'
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], fmt),
        ha="center", va="center",
        color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
fig.colorbar(im, location='bottom')  
plt.show()
# Out:
# Labels and frequencies in test set:  [2044  875 1876  304]
#
#  Confusion matrix SVM
#
#  [[2044    0    0    0]
#  [   0  367  501    7]
#  [   0    3 1873    0]
#  [   0    3    1  300]]
#
#  Confusion matrix SVM (normalized)
#
#  [[1.   0.   0.   0.  ]
#  [0.   0.42 0.57 0.01]
#  [0.   0.   1.   0.  ]
#  [0.   0.01 0.   0.99]]

# %%
#I try to do the same for polynomial degree 3 model
np.set_printoptions(precision=2, suppress=True) # for better aligned printing of confusion matrix use floatmode='fixed'

u, counts = np.unique(y_test, return_counts=True)
print("Labels and frequencies in test set: ", counts)

confusion_SVM = confusion_matrix(y_test, poly_svm_test)
print("\n Confusion matrix SVM  \n \n", confusion_SVM)
print("\n Confusion matrix SVM (normalized)   \n \n", confusion_SVM /counts[:,None] )


fig = plt.figure()
    
im = plt.imshow(confusion_SVM /counts[:,None], cmap="Blues",interpolation='nearest')
plt.xticks([0,1,2,3], ['Sunny', 'Rainy','Cloudy', 'Mostly clear'],ha="right",rotation=30)
plt.yticks([0,1,2,3], ['Sunny', 'Rainy','Cloudy', 'Mostly clear'],ha="right",rotation=30)
cm = confusion_SVM /counts[:,None]
fmt = '.2f'
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], fmt),
        ha="center", va="center",
        color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
fig.colorbar(im, location='bottom')  
plt.show()
# Out:
# Labels and frequencies in test set:  [2044  875 1876  304]
#
#  Confusion matrix SVM
#
#  [[2040    0    4    0]
#  [   1  571  299    4]
#  [   2    9 1863    2]
#  [   0    3    6  295]]
#
#  Confusion matrix SVM (normalized)
#
#  [[1.   0.   0.   0.  ]
#  [0.   0.65 0.34 0.  ]
#  [0.   0.   0.99 0.  ]
#  [0.   0.01 0.02 0.97]]
